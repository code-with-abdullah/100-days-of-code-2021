# %%
# Dataset taken from https://www.kaggle.com/yamaerenay/spotify-dataset-19212020-160k-tracks

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
spotify_data = pd.read_csv('Data.csv')

# %%
spotify_data.columns
# Out:
# Index(['acousticness', 'artists', 'danceability', 'duration_ms', 'energy',
#        'explicit', 'id', 'instrumentalness', 'key', 'liveness', 'loudness',
#        'mode', 'name', 'popularity', 'release_date', 'speechiness', 'tempo',
#        'valence', 'year'],
#       dtype='object')

# %%
spotify_data.head()
# Out:
#    acousticness                                   artists  danceability  \
# 0         0.995                       ['Carl Woitschach']         0.708
# 1         0.994  ['Robert Schumann', 'Vladimir Horowitz']         0.379
# 2         0.604                   ['Seweryn Goszczyński']         0.749
# 3         0.995                      ['Francisco Canaro']         0.781
# 4         0.990  ['Frédéric Chopin', 'Vladimir Horowitz']         0.210
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# 0       158648  0.1950         0  6KbQ3uYMLKb5jDxLF7wYDD             0.563
# 1       282133  0.0135         0  6KuQTIu1KoTTkLXKrwlLPV             0.901
# 2       104300  0.2200         0  6L63VW0PibdM1HDSBoqnoM             0.000
# 3       180760  0.1300         0  6M94FkXd15sOAOQYRnWPN8             0.887
# 4       687733  0.2040         0  6N6tiFZ9vLTSOIxkj8qKrd             0.908
#
#    key  liveness  loudness  mode  \
# 0   10    0.1510   -12.428     1
# ...

# %%
spotify_data[spotify_data['year'] == 2020].danceability.mean()
# Out:
# 0.6730774487471516

# %%
spotify_data[(spotify_data['year'] >= 2010) & (spotify_data['year'] <= 2020)].danceability.mean()
# Out:
# 0.6050484484669393

# %%
spotify_data[(spotify_data['year'] >= 2000) & (spotify_data['year'] <= 2010)].danceability.mean()
# Out:
# 0.5763772681818162

# %%
spotify_data.danceability.mean()
# Out:
# 0.5381497172015446

# %%
spotify_data[spotify_data['year'] == 2020].danceability.median()
# Out:
# 0.693

# %%
spotify_data.danceability.median()
# Out:
# 0.5479999999999999

# %%
sns.regplot(x='energy', y='danceability', data=spotify_data[spotify_data['year'] == 2000])

# %%
sns.regplot(x='energy', y='danceability', data=spotify_data[spotify_data['year'] == 2010])

# %%
sns.regplot(x='energy', y='danceability', data=spotify_data[spotify_data['year'] == 2020])

# %% [markdown]
# ## Comparing means of duration by increasing years

# %%
spotify_data[spotify_data['year'] < 2000].duration_ms.mean()
# Out:
# 231496.1416653022

# %%
spotify_data[(spotify_data['year'] >= 2000) & (spotify_data['year'] < 2010)].duration_ms.mean()
# Out:
# 240572.6453

# %%
spotify_data[(spotify_data['year'] >= 2010) & (spotify_data['year'] < 2020)].duration_ms.mean()
# Out:
# 224639.60577889447

# %%
spotify_data[spotify_data['year'] == 2020].duration_ms.mean()
# Out:
# 197114.66230068338

# %% [markdown]
# ## Comparing means of popularity by increasing years

# %%
spotify_data[spotify_data['year'] < 2000].popularity.mean()
# Out:
# 23.995196993442647

# %%
spotify_data[(spotify_data['year'] >= 2000) & (spotify_data['year'] < 2010)].popularity.mean()
# Out:
# 49.40865

# %%
spotify_data[(spotify_data['year'] >= 2010) & (spotify_data['year'] < 2020)].popularity.mean()
# Out:
# 59.562814070351756

# %%
spotify_data[spotify_data['year'] == 2020].popularity.mean()
# Out:
# 63.11104783599089

# %% [markdown]
# ## Analysis on the basis of 'key' feature

# %%
sns.lineplot(x='key', y='popularity', data=spotify_data[spotify_data['year'] < 2020])

# %%
sns.kdeplot(data=spotify_data.key)

# %% [markdown]
# ## Checking the distribution of data along time

# %%
sns.distplot(a=spotify_data[spotify_data['year'] < 2000].year, kde=False)

# %%
sns.distplot(a=spotify_data[(spotify_data['year'] >= 2000) & (spotify_data['year'] <= 2010)].year, kde=False)

# %%
sns.distplot(a=spotify_data[spotify_data['year'] > 2010].year, kde=False)
